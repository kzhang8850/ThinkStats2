# %% [markdown]
# # Report 1 - European Social Survey
#
# ## Kevin Zhang
#
# Data Science
#
# 1/25/2017
#
# http://www.europeansocialsurvey.org/
#
#
#
#
# http://www.europeansocialsurvey.org/docs/cumulative/ESS1-7_variable_list.pdf
#
# http://www.europeansocialsurvey.org/downloadwizard/
#
# https://github.com/AllenDowney/ProbablyOverthinkingIt/blob/master/ess.py

# %%
# %matplotlib inline

import thinkstats2, thinkplot
import pandas as pd
import numpy as np

# %%
def clean_dataframe(data):
    """
    Takes entire Pandas dataframe and cleans out 66, 77, 88, and 99, which are all bad responses, by replacing them with
    NaNs. Can then use dropna() to fully clean out data later.
    
    Input: Pandas dataframe
    Output: dataframe that has been cleaned out with NaNs
    """
    for series in data.columns:
        data[series].replace([66, 77, 88, 99], np.nan, inplace=True)
    return data

# %%
def make_and_plot_pmf(database, category, label):
    """
    Takes a category and makes a pmf. Then also plots the pmf using hist. Returns the pmf.
    
    Input: Category string
    Output: pmf
    """
    series = database[category].dropna()
    series_pmf = thinkstats2.Pmf(series, label=label)
    thinkplot.Hist(series_pmf)
    thinkplot.Config(xlabel=label, ylabel="pmf")
    
    return series_pmf

# %%
ess7 = pd.read_stata('../../ESS7e02_1.dta',convert_categoricals=False,convert_missing=False)
ess7 = clean_dataframe(ess7)

ess5 = pd.read_stata('../../ESS5e03_3.dta',convert_categoricals=False,convert_missing=False)
ess5 = clean_dataframe(ess5)

# %%
make_and_plot_pmf(ess7,'tvpol', 'watching politics on tv')
# Out:
# Pmf({0.0: 0.090889947619172962, 1.0: 0.31173172593508991, 2.0: 0.35166223579268774, 3.0: 0.13103103366586824, 4.0: 0.056987181174488699, 5.0: 0.026374667684451583, 6.0: 0.014029638598615462, 7.0: 0.017293569529625439})

# %%
make_and_plot_pmf(ess7,'polintr', 'interest in politics')
# Out:
# Pmf({1.0: 0.1202936419061839, 2.0: 0.36707726763717807, 3.0: 0.32604205549334331, 4.0: 0.18392434988179671, 7.0: 0.00044792833146696531, 8.0: 0.0019161378623864626, 9.0: 0.0002986188876446435})

# %%
make_and_plot_pmf(ess7,'trstlgl', 'trust in legal system')
# Out:
# Pmf({0.0: 0.066977758616317107, 1.0: 0.035860110065684361, 2.0: 0.062894676777155031, 3.0: 0.087266364028302609, 4.0: 0.088610484136846648, 5.0: 0.15178412923841647, 6.0: 0.11693844944333139, 7.0: 0.14468311734422157, 8.0: 0.14584971215541073, 9.0: 0.065151784129238416, 10.0: 0.033983414065075705})

# %%
make_and_plot_pmf(ess7,'hinctnta', 'total household income')
# Out:
# Pmf({1.0: 0.094233121138950729, 2.0: 0.10730973062811627, 3.0: 0.10872087553701903, 4.0: 0.11075919596098968, 5.0: 0.10825049390071811, 6.0: 0.10476966979209132, 7.0: 0.10216689140455956, 8.0: 0.098780143623192943, 9.0: 0.080497977358963899, 10.0: 0.084511900655398417})

# %%
make_and_plot_pmf(ess5,'tvpol', 'watching politics on tv')
# Out:
# Pmf({0.0: 0.086082268370607035, 1.0: 0.32777555910543132, 2.0: 0.36062300319488821, 3.0: 0.12470047923322684, 4.0: 0.052795527156549525, 5.0: 0.02172523961661342, 6.0: 0.010782747603833865, 7.0: 0.01551517571884984})

# %%
make_and_plot_pmf(ess5,'rdpol', 'watching politics on radio')
# Out:
# Pmf({0.0: 0.19021444817502436, 1.0: 0.43582800823134404, 2.0: 0.21477309650167875, 3.0: 0.06815227986569912, 4.0: 0.035768439293837322, 5.0: 0.016029459547276075, 6.0: 0.011182714177407125, 7.0: 0.028051554207733129})

# %%
make_and_plot_pmf(ess5,'nwsppol', 'watching politics on newspaper')
# Out:
# Pmf({0.0: 0.14930135003397241, 1.0: 0.6110011521077664, 2.0: 0.18031963605211071, 3.0: 0.037753685267791201, 4.0: 0.013588963398422497, 5.0: 0.0037517355469557766, 6.0: 0.001890638385867478, 7.0: 0.0023928392071135268})

# %%
make_and_plot_pmf(ess5,'polintr', 'political interest')
# Out:
# Pmf({1.0: 0.096782187654885818, 2.0: 0.33424835106180184, 3.0: 0.35003240687788328, 4.0: 0.21380914255213695, 7.0: 1.9062869343093523e-05, 8.0: 0.0022875443211712227, 9.0: 0.0028213046627778415})

# %%
make_and_plot_pmf(ess5,'trstlgl', 'trust in legal system')
# Out:
# Pmf({0.0: 0.10004138828120381, 1.0: 0.058909320246752987, 2.0: 0.081948796783539279, 3.0: 0.10374662488421135, 4.0: 0.093872563511302937, 5.0: 0.16797729557145391, 6.0: 0.097597508819645629, 7.0: 0.11736534027079761, 8.0: 0.10942273202073355, 9.0: 0.045586235440193933, 10.0: 0.023532194170164961})

# %%
make_and_plot_pmf(ess5,'trstplt', 'trust in politicians')
# Out:
# Pmf({0.0: 0.19653326037676855, 1.0: 0.10961072461502384, 2.0: 0.12676854529820997, 3.0: 0.13087235206753695, 4.0: 0.10990385366997578, 5.0: 0.15592511529742828, 6.0: 0.078206831861174081, 7.0: 0.056319862424763542, 8.0: 0.024564214804971469, 9.0: 0.0064097553349488001, 10.0: 0.0048854842491987812})

# %%
make_and_plot_pmf(ess7,'trstplt', 'trust in politicians')
# Out:
# Pmf({0.0: 0.15658793577172242, 1.0: 0.082755665347483048, 2.0: 0.11943233092183207, 3.0: 0.13133019081949032, 4.0: 0.11824758639812458, 5.0: 0.16281414635375968, 6.0: 0.10241738297496912, 7.0: 0.079453505079277065, 8.0: 0.033878651911976004, 9.0: 0.0072092964634115604, 10.0: 0.0058733079579541738})

# %%
make_and_plot_pmf(ess5,'happy', 'how happy')
# Out:
# Pmf({0.0: 0.0095589790933394876, 1.0: 0.0097320793183697796, 2.0: 0.017579289519743042, 3.0: 0.034966245456119094, 4.0: 0.043255822899236435, 5.0: 0.1251514626969015, 6.0: 0.092070086357778927, 7.0: 0.17823553170619122, 8.0: 0.25463043101956034, 9.0: 0.14407708730021349, 10.0: 0.09074298463254668})

# %%
make_and_plot_pmf(ess7,'happy', 'how happy')
# Out:
# Pmf({0.0: 0.0054979382731475696, 1.0: 0.00427339747594652, 2.0: 0.011745595401724353, 3.0: 0.024515806572535298, 4.0: 0.02973884793202549, 5.0: 0.091090840934649503, 6.0: 0.082169186555041851, 7.0: 0.18080719730101211, 8.0: 0.28896663751093338, 9.0: 0.17281019617643384, 10.0: 0.10838435586655004})

# %%
make_and_plot_pmf(ess5,'hinctnta', 'total household income')
# Out:
# Pmf({1.0: 0.11664742205934032, 2.0: 0.12051307796576134, 3.0: 0.11265625784426929, 4.0: 0.10956875345147848, 5.0: 0.10966916009839851, 6.0: 0.10223906822631658, 7.0: 0.095687534514784886, 8.0: 0.087278477835232696, 9.0: 0.072518700737988856, 10.0: 0.073221547266429043})
